# %% [markdown]
# # Classifying Urban sounds using Deep Learning
#
# ## 4 Model Refinement

# %% [markdown]
# ### Load Preprocessed data

# %%
# retrieve the preprocessed data from previous notebook

# %store -r x_train 
# %store -r x_test 
# %store -r y_train 
# %store -r y_test 
# %store -r yy 
# %store -r le

# %% [markdown]
# #### Model refinement
#
# In our inital attempt, we were able to achieve a Classification Accuracy score of:
#
# * Training data Accuracy:  92.3%
# * Testing data Accuracy:  87%
#
# We will now see if we can improve upon that score using a Convolutional Neural Network (CNN).

# %% [markdown]
# #### Feature Extraction refinement
#
# In the prevous feature extraction stage, the MFCC vectors would vary in size for the different audio files (depending on the samples duration).
#
# However, CNNs require a fixed size for all inputs. To overcome this we will zero pad the output vectors to make them all the same size.

# %%
import numpy as np
max_pad_len = 260

def extract_features(file_name):
   
    try:
        audio, sample_rate = librosa.load(file_name, res_type='kaiser_fast') 
        mfccs = librosa.feature.mfcc(y=audio, sr=sample_rate, n_mfcc=40)
        pad_width = max_pad_len - mfccs.shape[1]
        print(file_name, 'has a pad_width of :', pad_width)
        mfccs = np.pad(mfccs, pad_width=((0, 0), (0, pad_width)), mode='constant')
        
    except Exception as e:
        print("Error encountered while parsing file: ", file_name)
        return None 
     
    return mfccs

# %%
# Load various imports 
import pandas as pd
import os
import librosa

# Set the path to the full UrbanSound dataset 
fulldatasetpath = '../../UrbanSound8K/audio/'

metadata = pd.read_csv('../UrbanSound Dataset sample/metadata/UrbanSound8K.csv')

features = []

# Iterate through each sound file and extract the features 
for index, row in metadata.iterrows():
    print(index)
    file_name = os.path.join(os.path.abspath(fulldatasetpath),'fold'+str(row["fold"])+'/',str(row["slice_file_name"]))
    
    class_label = row["class_name"]
    data = extract_features(file_name)
    
    features.append([data, class_label])

# Convert into a Panda dataframe 
featuresdf = pd.DataFrame(features, columns=['feature','class_label'])

print('Finished feature extraction from ', len(featuresdf), ' files')
# Out:
# 0
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold5/100032-3-0-0.wav has a pad_width of : 246
# 1
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold5/100263-2-0-117.wav has a pad_width of : 87
# 2
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold5/100263-2-0-121.wav has a pad_width of : 87
# 3
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold5/100263-2-0-126.wav has a pad_width of : 87
# 4
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold5/100263-2-0-137.wav has a pad_width of : 87
# 5
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold5/100263-2-0-143.wav has a pad_width of : 87
# 6
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold5/100263-2-0-161.wav has a pad_width of : 87
# 7
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold5/100263-2-0-3.wav has a pad_width of : 87
# 8
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold5/100263-2-0-36.wav has a pad_width of : 87
# 9
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold10/100648-1-0-0.wav has a pad_width of : 232
# 10
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold10/100648-1-1-0.wav has a pad_width of : 214
# 11
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold10/100648-1-2-0.wav has a pad_width of : 242
# 12
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold10/100648-1-3-0.wav has a pad_width of : 190
# 13
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold10/100648-1-4-0.wav has a pad_width of : 179
# 14
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold2/100652-3-0-0.wav has a pad_width of : 87
# 15
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold2/100652-3-0-1.wav has a pad_width of : 87
# 16
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold2/100652-3-0-2.wav has a pad_width of : 87
# 17
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold2/100652-3-0-3.wav has a pad_width of : 87
# 18
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold10/100795-3-0-0.wav has a pad_width of : 87
# 19
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold10/100795-3-1-0.wav has a pad_width of : 87
# 20
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold10/100795-3-1-1.wav has a pad_width of : 87
# 21
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold10/100795-3-1-2.wav has a pad_width of : 87
# 22
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold5/100852-0-0-0.wav has a pad_width of : 87
# 23
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold5/100852-0-0-1.wav has a pad_width of : 87
# 24
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold5/100852-0-0-10.wav has a pad_width of : 87
# 25
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold5/100852-0-0-11.wav has a pad_width of : 87
# 26
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold5/100852-0-0-12.wav has a pad_width of : 87
# 27
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold5/100852-0-0-13.wav has a pad_width of : 87
# 28
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold5/100852-0-0-14.wav has a pad_width of : 87
# 29
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold5/100852-0-0-15.wav has a pad_width of : 87
# 30
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold5/100852-0-0-16.wav has a pad_width of : 87
# 31
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold5/100852-0-0-17.wav has a pad_width of : 87
# 32
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold5/100852-0-0-18.wav has a pad_width of : 87
# 33
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold5/100852-0-0-19.wav has a pad_width of : 87
# 34
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold5/100852-0-0-2.wav has a pad_width of : 87
# 35
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold5/100852-0-0-20.wav has a pad_width of : 87
# 36
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold5/100852-0-0-21.wav has a pad_width of : 87
# 37
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold5/100852-0-0-22.wav has a pad_width of : 87
# 38
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold5/100852-0-0-23.wav has a pad_width of : 87
# 39
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold5/100852-0-0-24.wav has a pad_width of : 87
# 40
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold5/100852-0-0-25.wav has a pad_width of : 87
# 41
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold5/100852-0-0-26.wav has a pad_width of : 87
# 42
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold5/100852-0-0-27.wav has a pad_width of : 87
# 43
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold5/100852-0-0-28.wav has a pad_width of : 87
# 44
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold5/100852-0-0-29.wav has a pad_width of : 87
# 45
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold5/100852-0-0-3.wav has a pad_width of : 87
# 46
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold5/100852-0-0-30.wav has a pad_width of : 87
# 47
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold5/100852-0-0-4.wav has a pad_width of : 87
# 48
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold5/100852-0-0-5.wav has a pad_width of : 87
# 49
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold5/100852-0-0-6.wav has a pad_width of : 87
# 50
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold5/100852-0-0-7.wav has a pad_width of : 87
# 51
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold5/100852-0-0-8.wav has a pad_width of : 87
# 52
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold5/100852-0-0-9.wav has a pad_width of : 87
# 53
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold6/101281-3-0-0.wav has a pad_width of : 87
# 54
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold6/101281-3-0-14.wav has a pad_width of : 87
# 55
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold6/101281-3-0-5.wav has a pad_width of : 87
# 56
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold10/101382-2-0-10.wav has a pad_width of : 87
# 57
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold10/101382-2-0-12.wav has a pad_width of : 87
# 58
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold10/101382-2-0-20.wav has a pad_width of : 87
# 59
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold10/101382-2-0-21.wav has a pad_width of : 87
# 60
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold10/101382-2-0-29.wav has a pad_width of : 87
# 61
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold10/101382-2-0-33.wav has a pad_width of : 87
# 62
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold10/101382-2-0-42.wav has a pad_width of : 87
# 63
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold10/101382-2-0-45.wav has a pad_width of : 87
# 64
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold1/101415-3-0-2.wav has a pad_width of : 87
# 65
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold1/101415-3-0-3.wav has a pad_width of : 87
# 66
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold1/101415-3-0-8.wav has a pad_width of : 87
# 67
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold9/101729-0-0-1.wav has a pad_width of : 87
# 68
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold9/101729-0-0-11.wav has a pad_width of : 87
# 69
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold9/101729-0-0-12.wav has a pad_width of : 87
# 70
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold9/101729-0-0-13.wav has a pad_width of : 87
# 71
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold9/101729-0-0-14.wav has a pad_width of : 87
# 72
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold9/101729-0-0-16.wav has a pad_width of : 87
# 73
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold9/101729-0-0-17.wav has a pad_width of : 87
# 74
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold9/101729-0-0-18.wav has a pad_width of : 87
# 75
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold9/101729-0-0-19.wav has a pad_width of : 87
# 76
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold9/101729-0-0-21.wav has a pad_width of : 87
# 77
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold9/101729-0-0-22.wav has a pad_width of : 87
# 78
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold9/101729-0-0-23.wav has a pad_width of : 87
# 79
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold9/101729-0-0-24.wav has a pad_width of : 87
# 80
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold9/101729-0-0-26.wav has a pad_width of : 87
# 81
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold9/101729-0-0-28.wav has a pad_width of : 87
# 82
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold9/101729-0-0-29.wav has a pad_width of : 87
# 83
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold9/101729-0-0-3.wav has a pad_width of : 87
# 84
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold9/101729-0-0-32.wav has a pad_width of : 87
# 85
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold9/101729-0-0-33.wav has a pad_width of : 87
# 86
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold9/101729-0-0-36.wav has a pad_width of : 87
# 87
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold9/101729-0-0-37.wav has a pad_width of : 87
# 88
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold9/101729-0-0-38.wav has a pad_width of : 87
# 89
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold9/101729-0-0-39.wav has a pad_width of : 87
# 90
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold9/101729-0-0-4.wav has a pad_width of : 87
# 91
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold9/101729-0-0-40.wav has a pad_width of : 87
# 92
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold9/101729-0-0-6.wav has a pad_width of : 87
# 93
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold9/101729-0-0-9.wav has a pad_width of : 87
# 94
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold7/101848-9-0-0.wav has a pad_width of : 87
# 95
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold7/101848-9-0-1.wav has a pad_width of : 87
# 96
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold7/101848-9-0-2.wav has a pad_width of : 87
# 97
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold7/101848-9-0-3.wav has a pad_width of : 87
# 98
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold7/101848-9-0-8.wav has a pad_width of : 87
# 99
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold7/101848-9-0-9.wav has a pad_width of : 87
# 100
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold4/102102-3-0-0.wav has a pad_width of : 126
# 101
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold10/102103-3-0-0.wav has a pad_width of : 237
# 102
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold10/102103-3-1-0.wav has a pad_width of : 243
# 103
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold2/102104-3-0-0.wav has a pad_width of : 225
# 104
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold3/102105-3-0-0.wav has a pad_width of : 87
# 105
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold1/102106-3-0-0.wav has a pad_width of : 189
# 106
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold1/102305-6-0-0.wav has a pad_width of : 147
# 107
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold5/102547-3-0-2.wav has a pad_width of : 87
# 108
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold5/102547-3-0-7.wav has a pad_width of : 87
# 109
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold5/102547-3-0-8.wav has a pad_width of : 87
# 110
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold1/102842-3-0-1.wav has a pad_width of : 87
# 111
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold1/102842-3-1-0.wav has a pad_width of : 87
# 112
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold1/102842-3-1-5.wav has a pad_width of : 87
# 113
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold1/102842-3-1-6.wav has a pad_width of : 87
# 114
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold7/102853-8-0-0.wav has a pad_width of : 87
# 115
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold7/102853-8-0-1.wav has a pad_width of : 87
# 116
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold7/102853-8-0-2.wav has a pad_width of : 87
# 117
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold7/102853-8-0-3.wav has a pad_width of : 87
# 118
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold7/102853-8-0-4.wav has a pad_width of : 87
# 119
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold7/102853-8-0-5.wav has a pad_width of : 87
# 120
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold7/102853-8-0-6.wav has a pad_width of : 87
# 121
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold7/102853-8-1-0.wav has a pad_width of : 87
# 122
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold10/102857-5-0-0.wav has a pad_width of : 87
# 123
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold10/102857-5-0-1.wav has a pad_width of : 87
# 124
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold10/102857-5-0-10.wav has a pad_width of : 87
# 125
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold10/102857-5-0-11.wav has a pad_width of : 87
# 126
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold10/102857-5-0-12.wav has a pad_width of : 87
# 127
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold10/102857-5-0-13.wav has a pad_width of : 87
# 128
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold10/102857-5-0-14.wav has a pad_width of : 87
# 129
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold10/102857-5-0-15.wav has a pad_width of : 87
# 130
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold10/102857-5-0-16.wav has a pad_width of : 87
# 131
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold10/102857-5-0-17.wav has a pad_width of : 87
# 132
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold10/102857-5-0-18.wav has a pad_width of : 87
# 133
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold10/102857-5-0-19.wav has a pad_width of : 87
# 134
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold10/102857-5-0-2.wav has a pad_width of : 87
# 135
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold10/102857-5-0-20.wav has a pad_width of : 87
# 136
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold10/102857-5-0-21.wav has a pad_width of : 87
# 137
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold10/102857-5-0-22.wav has a pad_width of : 87
# 138
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold10/102857-5-0-23.wav has a pad_width of : 87
# 139
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold10/102857-5-0-24.wav has a pad_width of : 87
# 140
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold10/102857-5-0-25.wav has a pad_width of : 87
# 141
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold10/102857-5-0-26.wav has a pad_width of : 87
# 142
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold10/102857-5-0-27.wav has a pad_width of : 87
# 143
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold10/102857-5-0-28.wav has a pad_width of : 87
# 144
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold10/102857-5-0-29.wav has a pad_width of : 87
# 145
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold10/102857-5-0-3.wav has a pad_width of : 87
# 146
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold10/102857-5-0-30.wav has a pad_width of : 87
# 147
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold10/102857-5-0-4.wav has a pad_width of : 87
# 148
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold10/102857-5-0-5.wav has a pad_width of : 87
# 149
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold10/102857-5-0-6.wav has a pad_width of : 87
# 150
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold10/102857-5-0-7.wav has a pad_width of : 87
# 151
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold10/102857-5-0-8.wav has a pad_width of : 87
# 152
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold10/102857-5-0-9.wav has a pad_width of : 87
# 153
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold2/102858-5-0-0.wav has a pad_width of : 87
# 154
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold2/102858-5-0-1.wav has a pad_width of : 87
# 155
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold2/102871-8-0-0.wav has a pad_width of : 87
# 156
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold2/102871-8-0-1.wav has a pad_width of : 87
# 157
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold2/102871-8-0-10.wav has a pad_width of : 87
# 158
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold2/102871-8-0-11.wav has a pad_width of : 87
# 159
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold2/102871-8-0-12.wav has a pad_width of : 87
# 160
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold2/102871-8-0-13.wav has a pad_width of : 87
# 161
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold2/102871-8-0-14.wav has a pad_width of : 87
# 162
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold2/102871-8-0-15.wav has a pad_width of : 87
# 163
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold2/102871-8-0-2.wav has a pad_width of : 87
# 164
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold2/102871-8-0-3.wav has a pad_width of : 87
# 165
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold2/102871-8-0-4.wav has a pad_width of : 87
# 166
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold2/102871-8-0-5.wav has a pad_width of : 87
# 167
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold2/102871-8-0-6.wav has a pad_width of : 87
# 168
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold2/102871-8-0-7.wav has a pad_width of : 87
# 169
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold2/102871-8-0-8.wav has a pad_width of : 87
# 170
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold2/102871-8-0-9.wav has a pad_width of : 87
# 171
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold1/103074-7-0-0.wav has a pad_width of : 87
# 172
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold1/103074-7-0-1.wav has a pad_width of : 87
# 173
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold1/103074-7-0-2.wav has a pad_width of : 87
# 174
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold1/103074-7-1-0.wav has a pad_width of : 87
# 175
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold1/103074-7-1-1.wav has a pad_width of : 87
# 176
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold1/103074-7-1-2.wav has a pad_width of : 87
# 177
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold1/103074-7-1-3.wav has a pad_width of : 87
# 178
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold1/103074-7-1-4.wav has a pad_width of : 87
# 179
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold1/103074-7-1-5.wav has a pad_width of : 87
# 180
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold1/103074-7-1-6.wav has a pad_width of : 87
# 181
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold1/103074-7-2-0.wav has a pad_width of : 200
# 182
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold1/103074-7-3-0.wav has a pad_width of : 87
# 183
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold1/103074-7-3-1.wav has a pad_width of : 87
# 184
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold1/103074-7-3-2.wav has a pad_width of : 87
# 185
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold1/103074-7-3-3.wav has a pad_width of : 87
# 186
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold1/103074-7-4-0.wav has a pad_width of : 87
# 187
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold1/103074-7-4-1.wav has a pad_width of : 87
# 188
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold1/103074-7-4-2.wav has a pad_width of : 87
# 189
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold1/103074-7-4-3.wav has a pad_width of : 87
# 190
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold1/103074-7-4-4.wav has a pad_width of : 87
# 191
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold1/103074-7-4-5.wav has a pad_width of : 87
# 192
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold1/103074-7-4-6.wav has a pad_width of : 87
# 193
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold8/103076-3-0-0.wav has a pad_width of : 151
# 194
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold8/103076-3-1-0.wav has a pad_width of : 218
# 195
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold8/103076-3-2-0.wav has a pad_width of : 240
# 196
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold3/103199-4-0-0.wav has a pad_width of : 87
# 197
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold3/103199-4-0-3.wav has a pad_width of : 87
# 198
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold3/103199-4-0-4.wav has a pad_width of : 87
# 199
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold3/103199-4-0-5.wav has a pad_width of : 87
# 200
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold3/103199-4-0-6.wav has a pad_width of : 87
# 201
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold3/103199-4-1-0.wav has a pad_width of : 194
# 202
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold3/103199-4-2-0.wav has a pad_width of : 87
# 203
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold3/103199-4-2-1.wav has a pad_width of : 87
# 204
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold3/103199-4-2-10.wav has a pad_width of : 87
# 205
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold3/103199-4-2-11.wav has a pad_width of : 87
# 206
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold3/103199-4-2-2.wav has a pad_width of : 87
# 207
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold3/103199-4-2-3.wav has a pad_width of : 87
# 208
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold3/103199-4-2-4.wav has a pad_width of : 87
# 209
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold3/103199-4-2-5.wav has a pad_width of : 87
# 210
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold3/103199-4-2-6.wav has a pad_width of : 87
# 211
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold3/103199-4-2-7.wav has a pad_width of : 87
# 212
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold3/103199-4-2-8.wav has a pad_width of : 87
# 213
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold3/103199-4-2-9.wav has a pad_width of : 87
# 214
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold3/103199-4-4-0.wav has a pad_width of : 151
# 215
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold3/103199-4-6-0.wav has a pad_width of : 202
# 216
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold3/103199-4-7-2.wav has a pad_width of : 87
# 217
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold9/103249-5-0-0.wav has a pad_width of : 87
# 218
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold9/103249-5-0-1.wav has a pad_width of : 87
# 219
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold9/103249-5-0-10.wav has a pad_width of : 87
# 220
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold9/103249-5-0-11.wav has a pad_width of : 87
# 221
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold9/103249-5-0-12.wav has a pad_width of : 87
# 222
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold9/103249-5-0-13.wav has a pad_width of : 87
# 223
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold9/103249-5-0-14.wav has a pad_width of : 87
# 224
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold9/103249-5-0-15.wav has a pad_width of : 87
# 225
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold9/103249-5-0-16.wav has a pad_width of : 87
# 226
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold9/103249-5-0-17.wav has a pad_width of : 87
# 227
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold9/103249-5-0-18.wav has a pad_width of : 87
# 228
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold9/103249-5-0-19.wav has a pad_width of : 87
# 229
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold9/103249-5-0-2.wav has a pad_width of : 87
# 230
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold9/103249-5-0-3.wav has a pad_width of : 87
# 231
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold9/103249-5-0-4.wav has a pad_width of : 87
# 232
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold9/103249-5-0-5.wav has a pad_width of : 87
# 233
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold9/103249-5-0-6.wav has a pad_width of : 87
# 234
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold9/103249-5-0-7.wav has a pad_width of : 87
# 235
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold9/103249-5-0-8.wav has a pad_width of : 87
# 236
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold9/103249-5-0-9.wav has a pad_width of : 87
# 237
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold1/103258-5-0-0.wav has a pad_width of : 87
# 238
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold1/103258-5-0-1.wav has a pad_width of : 87
# 239
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold1/103258-5-0-10.wav has a pad_width of : 87
# 240
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold1/103258-5-0-11.wav has a pad_width of : 87
# 241
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold1/103258-5-0-12.wav has a pad_width of : 87
# 242
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold1/103258-5-0-13.wav has a pad_width of : 87
# 243
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold1/103258-5-0-14.wav has a pad_width of : 87
# 244
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold1/103258-5-0-15.wav has a pad_width of : 87
# 245
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold1/103258-5-0-16.wav has a pad_width of : 87
# 246
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold1/103258-5-0-17.wav has a pad_width of : 87
# 247
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold1/103258-5-0-18.wav has a pad_width of : 87
# 248
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold1/103258-5-0-19.wav has a pad_width of : 87
# 249
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold1/103258-5-0-2.wav has a pad_width of : 87
# 250
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold1/103258-5-0-3.wav has a pad_width of : 87
# 251
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold1/103258-5-0-4.wav has a pad_width of : 87
# 252
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold1/103258-5-0-5.wav has a pad_width of : 87
# 253
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold1/103258-5-0-6.wav has a pad_width of : 87
# 254
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold1/103258-5-0-7.wav has a pad_width of : 87
# 255
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold1/103258-5-0-8.wav has a pad_width of : 87
# 256
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold1/103258-5-0-9.wav has a pad_width of : 87
# 257
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold3/103357-4-0-0.wav has a pad_width of : 87
# 258
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold3/103357-4-0-1.wav has a pad_width of : 87
# 259
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold10/103438-5-0-0.wav has a pad_width of : 87
# 260
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold10/103438-5-0-1.wav has a pad_width of : 87
# 261
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold10/103438-5-0-2.wav has a pad_width of : 87
# 262
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold6/104327-2-0-15.wav has a pad_width of : 87
# 263
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold6/104327-2-0-19.wav has a pad_width of : 87
# 264
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold6/104327-2-0-26.wav has a pad_width of : 87
# 265
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold6/104327-2-0-28.wav has a pad_width of : 87
# 266
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold6/104327-2-0-3.wav has a pad_width of : 87
# 267
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold6/104327-2-0-30.wav has a pad_width of : 87
# 268
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold6/104327-2-0-34.wav has a pad_width of : 87
# 269
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold6/104327-2-0-4.wav has a pad_width of : 87
# 270
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold5/104421-2-0-1.wav has a pad_width of : 87
# 271
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold5/104421-2-0-15.wav has a pad_width of : 87
# 272
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold5/104421-2-0-20.wav has a pad_width of : 87
# 273
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold5/104421-2-0-29.wav has a pad_width of : 87
# 274
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold5/104421-2-0-3.wav has a pad_width of : 87
# 275
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold5/104421-2-0-5.wav has a pad_width of : 87
# 276
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold5/104421-2-0-7.wav has a pad_width of : 87
# 277
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold5/104421-2-1-3.wav has a pad_width of : 87
# 278
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold7/104625-4-0-15.wav has a pad_width of : 87
# 279
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold7/104625-4-0-21.wav has a pad_width of : 87
# 280
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold7/104625-4-0-27.wav has a pad_width of : 87
# 281
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold7/104625-4-0-29.wav has a pad_width of : 87
# 282
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold7/104625-4-0-3.wav has a pad_width of : 87
# 283
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold7/104625-4-0-35.wav has a pad_width of : 87
# 284
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold7/104625-4-0-40.wav has a pad_width of : 87
# 285
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold7/104625-4-0-41.wav has a pad_width of : 87
# 286
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold7/104625-4-0-45.wav has a pad_width of : 87
# 287
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold7/104625-4-0-48.wav has a pad_width of : 87
# 288
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold7/104625-4-0-51.wav has a pad_width of : 87
# 289
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold7/104625-4-0-52.wav has a pad_width of : 87
# 290
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold7/104625-4-0-53.wav has a pad_width of : 87
# 291
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold7/104625-4-0-55.wav has a pad_width of : 87
# 292
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold7/104625-4-0-57.wav has a pad_width of : 87
# 293
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold7/104625-4-0-66.wav has a pad_width of : 87
# 294
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold7/104625-4-1-20.wav has a pad_width of : 87
# 295
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold7/104625-4-1-8.wav has a pad_width of : 87
# 296
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold2/104817-4-0-0.wav has a pad_width of : 87
# 297
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold2/104817-4-0-1.wav has a pad_width of : 87
# 298
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold2/104817-4-0-10.wav has a pad_width of : 87
# 299
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold2/104817-4-0-11.wav has a pad_width of : 87
# 300
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold2/104817-4-0-2.wav has a pad_width of : 87
# 301
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold2/104817-4-0-3.wav has a pad_width of : 87
# 302
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold2/104817-4-0-4.wav has a pad_width of : 87
# 303
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold2/104817-4-0-5.wav has a pad_width of : 87
# 304
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold2/104817-4-0-6.wav has a pad_width of : 87
# 305
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold2/104817-4-0-7.wav has a pad_width of : 87
# 306
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold2/104817-4-0-8.wav has a pad_width of : 87
# 307
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold2/104817-4-0-9.wav has a pad_width of : 87
# 308
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold5/104998-7-0-5.wav has a pad_width of : 87
# 309
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold5/104998-7-10-1.wav has a pad_width of : 87
# 310
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold5/104998-7-10-10.wav has a pad_width of : 87
# 311
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold5/104998-7-10-13.wav has a pad_width of : 87
# 312
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold5/104998-7-10-15.wav has a pad_width of : 87
# 313
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold5/104998-7-10-8.wav has a pad_width of : 87
# 314
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold5/104998-7-10-9.wav has a pad_width of : 87
# 315
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold5/104998-7-11-0.wav has a pad_width of : 87
# 316
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold5/104998-7-11-2.wav has a pad_width of : 87
# 317
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold5/104998-7-12-2.wav has a pad_width of : 87
# 318
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold5/104998-7-14-1.wav has a pad_width of : 87
# 319
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold5/104998-7-14-5.wav has a pad_width of : 87
# 320
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold5/104998-7-14-6.wav has a pad_width of : 87
# 321
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold5/104998-7-15-1.wav has a pad_width of : 87
# 322
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold5/104998-7-15-3.wav has a pad_width of : 87
# 323
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold5/104998-7-15-5.wav has a pad_width of : 87
# 324
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold5/104998-7-15-9.wav has a pad_width of : 87
# 325
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold5/104998-7-16-0.wav has a pad_width of : 87
# 326
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold5/104998-7-16-10.wav has a pad_width of : 87
# 327
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold5/104998-7-16-11.wav has a pad_width of : 87
# 328
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold5/104998-7-16-5.wav has a pad_width of : 87
# 329
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold5/104998-7-16-6.wav has a pad_width of : 87
# 330
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold5/104998-7-16-7.wav has a pad_width of : 87
# 331
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold5/104998-7-17-0.wav has a pad_width of : 87
# 332
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold5/104998-7-17-1.wav has a pad_width of : 87
# 333
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold5/104998-7-17-12.wav has a pad_width of : 87
# 334
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold5/104998-7-17-14.wav has a pad_width of : 87
# 335
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold5/104998-7-17-4.wav has a pad_width of : 87
# 336
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold5/104998-7-17-7.wav has a pad_width of : 87
# 337
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold5/104998-7-17-8.wav has a pad_width of : 87
# 338
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold5/104998-7-18-12.wav has a pad_width of : 87
# 339
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold5/104998-7-18-13.wav has a pad_width of : 87
# 340
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold5/104998-7-18-3.wav has a pad_width of : 87
# 341
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold5/104998-7-18-9.wav has a pad_width of : 87
# 342
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold5/104998-7-19-0.wav has a pad_width of : 87
# 343
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold5/104998-7-19-3.wav has a pad_width of : 87
# 344
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold5/104998-7-19-6.wav has a pad_width of : 87
# 345
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold5/104998-7-19-7.wav has a pad_width of : 87
# 346
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold5/104998-7-19-8.wav has a pad_width of : 87
# 347
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold5/104998-7-19-9.wav has a pad_width of : 87
# 348
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold5/104998-7-2-4.wav has a pad_width of : 87
# 349
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold5/104998-7-2-5.wav has a pad_width of : 87
# 350
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold5/104998-7-2-6.wav has a pad_width of : 87
# 351
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold5/104998-7-3-1.wav has a pad_width of : 87
# 352
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold5/104998-7-7-0.wav has a pad_width of : 87
# 353
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold5/104998-7-7-1.wav has a pad_width of : 87
# 354
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold5/104998-7-7-4.wav has a pad_width of : 87
# 355
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold5/104998-7-7-7.wav has a pad_width of : 87
# 356
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold5/104998-7-7-9.wav has a pad_width of : 87
# 357
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold5/104998-7-8-13.wav has a pad_width of : 87
# 358
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold5/104998-7-8-14.wav has a pad_width of : 87
# 359
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold5/104998-7-8-15.wav has a pad_width of : 87
# 360
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold5/104998-7-8-17.wav has a pad_width of : 87
# 361
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold5/104998-7-8-4.wav has a pad_width of : 87
# 362
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold5/104998-7-8-6.wav has a pad_width of : 87
# 363
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold5/104998-7-8-7.wav has a pad_width of : 87
# 364
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold5/104998-7-9-0.wav has a pad_width of : 87
# 365
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold5/104998-7-9-13.wav has a pad_width of : 87
# 366
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold5/104998-7-9-9.wav has a pad_width of : 87
# 367
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold9/105029-7-0-0.wav has a pad_width of : 87
# 368
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold9/105029-7-0-1.wav has a pad_width of : 87
# 369
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold9/105029-7-0-2.wav has a pad_width of : 87
# 370
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold9/105029-7-0-3.wav has a pad_width of : 87
# 371
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold9/105029-7-0-4.wav has a pad_width of : 87
# 372
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold9/105029-7-0-5.wav has a pad_width of : 87
# 373
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold9/105029-7-0-6.wav has a pad_width of : 87
# 374
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold9/105029-7-1-0.wav has a pad_width of : 87
# 375
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold9/105029-7-1-1.wav has a pad_width of : 87
# 376
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold9/105029-7-1-10.wav has a pad_width of : 87
# 377
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold9/105029-7-1-11.wav has a pad_width of : 87
# 378
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold9/105029-7-1-12.wav has a pad_width of : 87
# 379
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold9/105029-7-1-13.wav has a pad_width of : 87
# 380
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold9/105029-7-1-2.wav has a pad_width of : 87
# 381
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold9/105029-7-1-3.wav has a pad_width of : 87
# 382
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold9/105029-7-1-4.wav has a pad_width of : 87
# 383
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold9/105029-7-1-5.wav has a pad_width of : 87
# 384
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold9/105029-7-1-6.wav has a pad_width of : 87
# 385
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold9/105029-7-1-7.wav has a pad_width of : 87
# 386
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold9/105029-7-1-8.wav has a pad_width of : 87
# 387
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold9/105029-7-1-9.wav has a pad_width of : 87
# 388
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold9/105029-7-2-0.wav has a pad_width of : 87
# 389
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold9/105029-7-2-1.wav has a pad_width of : 87
# 390
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold9/105029-7-2-10.wav has a pad_width of : 87
# 391
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold9/105029-7-2-11.wav has a pad_width of : 87
# 392
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold9/105029-7-2-12.wav has a pad_width of : 87
# 393
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold9/105029-7-2-13.wav has a pad_width of : 87
# 394
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold9/105029-7-2-14.wav has a pad_width of : 87
# 395
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold9/105029-7-2-15.wav has a pad_width of : 87
# 396
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold9/105029-7-2-16.wav has a pad_width of : 87
# 397
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold9/105029-7-2-2.wav has a pad_width of : 87
# 398
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold9/105029-7-2-3.wav has a pad_width of : 87
# 399
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold9/105029-7-2-4.wav has a pad_width of : 87
# 400
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold9/105029-7-2-5.wav has a pad_width of : 87
# 401
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold9/105029-7-2-6.wav has a pad_width of : 87
# 402
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold9/105029-7-2-7.wav has a pad_width of : 87
# 403
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold9/105029-7-2-8.wav has a pad_width of : 87
# 404
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold9/105029-7-2-9.wav has a pad_width of : 87
# 405
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold9/105029-7-3-0.wav has a pad_width of : 87
# 406
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold9/105029-7-3-1.wav has a pad_width of : 87
# 407
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold9/105029-7-3-2.wav has a pad_width of : 87
# 408
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold9/105029-7-3-3.wav has a pad_width of : 87
# 409
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold9/105029-7-3-4.wav has a pad_width of : 87
# 410
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold9/105029-7-3-5.wav has a pad_width of : 87
# 411
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold9/105029-7-3-6.wav has a pad_width of : 87
# 412
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold9/105029-7-3-7.wav has a pad_width of : 87
# 413
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold9/105029-7-4-0.wav has a pad_width of : 87
# 414
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold9/105029-7-4-1.wav has a pad_width of : 87
# 415
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold9/105029-7-4-2.wav has a pad_width of : 87
# 416
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold9/105029-7-4-3.wav has a pad_width of : 87
# 417
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold9/105088-3-0-10.wav has a pad_width of : 87
# 418
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold9/105088-3-0-11.wav has a pad_width of : 87
# 419
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold9/105088-3-0-19.wav has a pad_width of : 87
# 420
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold9/105088-3-0-8.wav has a pad_width of : 87
# 421
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold7/105289-8-0-0.wav has a pad_width of : 87
# 422
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold7/105289-8-0-1.wav has a pad_width of : 87
# 423
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold7/105289-8-0-2.wav has a pad_width of : 87
# 424
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold7/105289-8-0-3.wav has a pad_width of : 87
# 425
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold7/105289-8-0-4.wav has a pad_width of : 87
# 426
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold7/105289-8-0-5.wav has a pad_width of : 87
# 427
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold7/105289-8-1-0.wav has a pad_width of : 87
# 428
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold7/105289-8-1-1.wav has a pad_width of : 87
# 429
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold7/105289-8-1-2.wav has a pad_width of : 87
# 430
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold7/105289-8-1-3.wav has a pad_width of : 87
# 431
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold7/105289-8-1-4.wav has a pad_width of : 87
# 432
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold7/105289-8-2-0.wav has a pad_width of : 87
# 433
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold7/105289-8-2-1.wav has a pad_width of : 87
# 434
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold7/105289-8-2-2.wav has a pad_width of : 87
# 435
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold7/105289-8-2-3.wav has a pad_width of : 87
# 436
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold7/105289-8-2-4.wav has a pad_width of : 87
# 437
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold7/105289-8-2-5.wav has a pad_width of : 87
# 438
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold7/105289-8-2-6.wav has a pad_width of : 87
# 439
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold7/105289-8-2-7.wav has a pad_width of : 87
# 440
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold6/105319-3-0-22.wav has a pad_width of : 87
# 441
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold6/105319-3-0-29.wav has a pad_width of : 87
# 442
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold6/105319-3-0-39.wav has a pad_width of : 87
# 443
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold1/105415-2-0-1.wav has a pad_width of : 87
# 444
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold1/105415-2-0-15.wav has a pad_width of : 87
# 445
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold1/105415-2-0-19.wav has a pad_width of : 87
# 446
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold1/105415-2-0-21.wav has a pad_width of : 87
# 447
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold1/105415-2-0-24.wav has a pad_width of : 87
# 448
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold1/105415-2-0-4.wav has a pad_width of : 87
# 449
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold1/105415-2-0-6.wav has a pad_width of : 87
# 450
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold1/105415-2-0-8.wav has a pad_width of : 87
# 451
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold5/105425-9-0-1.wav has a pad_width of : 87
# 452
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold5/105425-9-0-10.wav has a pad_width of : 87
# 453
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold5/105425-9-0-12.wav has a pad_width of : 87
# 454
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold5/105425-9-0-13.wav has a pad_width of : 87
# 455
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold5/105425-9-0-14.wav has a pad_width of : 87
# 456
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold5/105425-9-0-23.wav has a pad_width of : 87
# 457
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold10/106014-5-0-0.wav has a pad_width of : 87
# 458
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold10/106014-5-0-1.wav has a pad_width of : 87
# 459
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold10/106014-5-0-2.wav has a pad_width of : 87
# 460
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold10/106014-5-0-3.wav has a pad_width of : 87
# 461
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold10/106014-5-0-4.wav has a pad_width of : 87
# 462
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold2/106015-5-0-0.wav has a pad_width of : 87
# 463
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold2/106015-5-0-1.wav has a pad_width of : 87
# 464
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold2/106015-5-0-10.wav has a pad_width of : 87
# 465
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold2/106015-5-0-11.wav has a pad_width of : 87
# 466
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold2/106015-5-0-12.wav has a pad_width of : 87
# 467
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold2/106015-5-0-13.wav has a pad_width of : 87
# 468
# ...
# 8663
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold4/99157-9-0-10.wav has a pad_width of : 87
# 8664
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold4/99157-9-0-15.wav has a pad_width of : 87
# 8665
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold4/99157-9-0-16.wav has a pad_width of : 87
# 8666
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold4/99157-9-0-22.wav has a pad_width of : 87
# 8667
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold4/99157-9-0-24.wav has a pad_width of : 87
# 8668
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold4/99157-9-0-31.wav has a pad_width of : 87
# 8669
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold8/99179-9-0-12.wav has a pad_width of : 87
# 8670
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold8/99179-9-0-17.wav has a pad_width of : 87
# 8671
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold8/99179-9-0-19.wav has a pad_width of : 87
# 8672
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold8/99179-9-0-38.wav has a pad_width of : 87
# 8673
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold8/99179-9-0-53.wav has a pad_width of : 87
# 8674
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold8/99179-9-0-58.wav has a pad_width of : 87
# 8675
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold1/99180-9-0-0.wav has a pad_width of : 87
# 8676
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold1/99180-9-0-2.wav has a pad_width of : 87
# 8677
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold1/99180-9-0-36.wav has a pad_width of : 87
# 8678
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold1/99180-9-0-48.wav has a pad_width of : 87
# 8679
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold1/99180-9-0-49.wav has a pad_width of : 87
# 8680
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold1/99180-9-0-7.wav has a pad_width of : 87
# 8681
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold5/99185-3-0-0.wav has a pad_width of : 233
# 8682
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold10/99192-4-0-0.wav has a pad_width of : 87
# 8683
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold10/99192-4-0-1.wav has a pad_width of : 87
# 8684
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold10/99192-4-0-12.wav has a pad_width of : 87
# 8685
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold10/99192-4-0-15.wav has a pad_width of : 87
# 8686
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold10/99192-4-0-17.wav has a pad_width of : 87
# 8687
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold10/99192-4-0-18.wav has a pad_width of : 87
# 8688
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold10/99192-4-0-20.wav has a pad_width of : 87
# 8689
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold10/99192-4-0-24.wav has a pad_width of : 87
# 8690
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold10/99192-4-0-26.wav has a pad_width of : 87
# 8691
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold10/99192-4-0-27.wav has a pad_width of : 87
# 8692
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold10/99192-4-0-28.wav has a pad_width of : 87
# 8693
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold10/99192-4-0-3.wav has a pad_width of : 87
# 8694
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold10/99192-4-0-30.wav has a pad_width of : 87
# 8695
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold10/99192-4-0-32.wav has a pad_width of : 87
# 8696
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold10/99192-4-0-33.wav has a pad_width of : 87
# 8697
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold10/99192-4-0-38.wav has a pad_width of : 87
# 8698
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold10/99192-4-0-40.wav has a pad_width of : 87
# 8699
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold10/99192-4-0-41.wav has a pad_width of : 87
# 8700
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold10/99192-4-0-43.wav has a pad_width of : 87
# 8701
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold10/99192-4-0-47.wav has a pad_width of : 87
# 8702
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold10/99192-4-0-48.wav has a pad_width of : 87
# 8703
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold10/99192-4-0-49.wav has a pad_width of : 87
# 8704
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold10/99192-4-0-52.wav has a pad_width of : 87
# 8705
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold10/99192-4-0-53.wav has a pad_width of : 87
# 8706
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold10/99192-4-0-54.wav has a pad_width of : 87
# 8707
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold10/99192-4-0-55.wav has a pad_width of : 87
# 8708
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold10/99192-4-0-7.wav has a pad_width of : 87
# 8709
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold9/99500-2-0-1.wav has a pad_width of : 87
# 8710
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold9/99500-2-0-11.wav has a pad_width of : 87
# 8711
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold9/99500-2-0-2.wav has a pad_width of : 87
# 8712
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold9/99500-2-0-23.wav has a pad_width of : 87
# 8713
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold9/99500-2-0-29.wav has a pad_width of : 87
# 8714
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold9/99500-2-0-39.wav has a pad_width of : 87
# 8715
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold9/99500-2-0-41.wav has a pad_width of : 87
# 8716
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold9/99500-2-0-50.wav has a pad_width of : 87
# 8717
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold6/99710-9-0-11.wav has a pad_width of : 87
# 8718
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold6/99710-9-0-12.wav has a pad_width of : 87
# 8719
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold6/99710-9-0-16.wav has a pad_width of : 87
# 8720
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold6/99710-9-0-2.wav has a pad_width of : 87
# 8721
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold6/99710-9-0-5.wav has a pad_width of : 87
# 8722
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold6/99710-9-0-6.wav has a pad_width of : 87
# 8723
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold7/99812-1-0-0.wav has a pad_width of : 87
# 8724
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold7/99812-1-0-1.wav has a pad_width of : 87
# 8725
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold7/99812-1-0-2.wav has a pad_width of : 87
# 8726
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold7/99812-1-1-0.wav has a pad_width of : 87
# 8727
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold7/99812-1-2-0.wav has a pad_width of : 87
# 8728
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold7/99812-1-3-0.wav has a pad_width of : 167
# 8729
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold7/99812-1-4-0.wav has a pad_width of : 109
# 8730
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold7/99812-1-5-0.wav has a pad_width of : 151
# 8731
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold7/99812-1-6-0.wav has a pad_width of : 151
# 8732
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold11/1-20133-A-39.wav has a pad_width of : 44
# 8733
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold11/1-84536-A-39.wav has a pad_width of : 44
# 8734
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold11/1-84704-A-39.wav has a pad_width of : 44
# 8735
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold11/1-84705-A-39.wav has a pad_width of : 44
# 8736
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold11/1-85168-A-39.wav has a pad_width of : 44
# 8737
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold11/1-85184-A-39.wav has a pad_width of : 44
# 8738
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold11/1-88807-A-39.wav has a pad_width of : 44
# 8739
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold11/1-977-A-39.wav has a pad_width of : 44
# 8740
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold11/2-106881-A-39.wav has a pad_width of : 44
# 8741
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold11/2-112213-A-39.wav has a pad_width of : 44
# 8742
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold11/2-112213-B-39.wav has a pad_width of : 44
# 8743
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold11/2-141563-A-39.wav has a pad_width of : 44
# 8744
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold11/2-173559-A-39.wav has a pad_width of : 44
# 8745
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold11/2-173607-A-39.wav has a pad_width of : 44
# 8746
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold11/2-173618-A-39.wav has a pad_width of : 44
# 8747
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold11/2-250710-A-39.wav has a pad_width of : 44
# 8748
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold11/3-203371-A-39.wav has a pad_width of : 44
# 8749
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold11/3-203373-A-39.wav has a pad_width of : 44
# 8750
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold11/3-203374-A-39.wav has a pad_width of : 44
# 8751
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold11/3-203375-A-39.wav has a pad_width of : 44
# 8752
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold11/3-203377-A-39.wav has a pad_width of : 44
# 8753
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold11/3-216280-A-39.wav has a pad_width of : 44
# 8754
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold11/3-216281-A-39.wav has a pad_width of : 44
# 8755
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold11/3-216284-A-39.wav has a pad_width of : 44
# 8756
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold11/4-204115-A-39.wav has a pad_width of : 44
# 8757
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold11/4-204119-A-39.wav has a pad_width of : 44
# 8758
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold11/4-204121-A-39.wav has a pad_width of : 44
# 8759
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold11/4-204123-A-39.wav has a pad_width of : 44
# 8760
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold11/4-204777-A-39.wav has a pad_width of : 44
# 8761
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold11/4-204777-B-39.wav has a pad_width of : 44
# 8762
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold11/4-204777-C-39.wav has a pad_width of : 44
# 8763
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold11/4-212698-A-39.wav has a pad_width of : 44
# 8764
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold11/5-221528-A-39.wav has a pad_width of : 44
# 8765
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold11/5-221529-A-39.wav has a pad_width of : 44
# 8766
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold11/5-233605-A-39.wav has a pad_width of : 44
# 8767
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold11/5-233607-A-39.wav has a pad_width of : 44
# 8768
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold11/5-257642-A-39.wav has a pad_width of : 44
# 8769
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold11/5-260432-A-39.wav has a pad_width of : 44
# 8770
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold11/5-260433-A-39.wav has a pad_width of : 44
# 8771
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold11/5-260434-A-39.wav has a pad_width of : 44
# 8772
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold11/66520__connum__breaking-a-bottle-no2.wav has a pad_width of : 159
# 8773
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold11/85184__cmusounddesign__mp-glass-break.wav has a pad_width of : 1
# 8774
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold11/141563__avrahamy__glass-break.wav has a pad_width of : 179
# 8775
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold11/159462__gr3ave5y__samgreaves-glasssmash-01.wav has a pad_width of : 168
# 8776
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold11/173558__gevaroy__003.wav has a pad_width of : 137
# 8777
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold11/173559__gevaroy__002.wav has a pad_width of : 46
# 8778
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold11/173576__gevaroy__006.wav has a pad_width of : 51
# 8779
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold11/173580__gevaroy__008.wav has a pad_width of : 96
# 8780
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold11/173581__gevaroy__007.wav has a pad_width of : 108
# 8781
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold11/173593__gevaroy__017.wav has a pad_width of : 97
# 8782
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold11/173607__gevaroy__009.wav has a pad_width of : 59
# 8783
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold11/173613__gevaroy__017-01.wav has a pad_width of : 68
# 8784
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold11/173621__gevaroy__028.wav has a pad_width of : 27
# 8785
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold11/244238__chewiesmissus__glass-smash.wav has a pad_width of : 190
# 8786
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold11/315647__thesoundcatcher__glas-multiple-slices-drop-on-floor-debris-01.wav has a pad_width of : 150
# 8787
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold11/341070__hifijohn__breaking-glass.wav has a pad_width of : 114
# 8788
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold11/979__rhumphries__rbh-glass-break-03.wav has a pad_width of : 158
# 8789
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold11/42903__freqman__glass-break-5.wav has a pad_width of : 143
# 8790
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold11/65918__bristolstories__wine-glass-bits-hit.wav has a pad_width of : 233
# 8791
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold11/116329__david-bowman__bball-on-lamp.wav has a pad_width of : 209
# 8792
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold11/160759__cosmicembers__smashing-glass.wav has a pad_width of : 156
# 8793
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold11/171994__drewkelly__glass1.wav has a pad_width of : 198
# 8794
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold11/179249__jorickhoofd__breaking-saucer.wav has a pad_width of : 54
# 8795
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold11/194683__kingsrow__breakingvase03.wav has a pad_width of : 15
# 8796
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold11/194684__kingsrow__breakingvase02.wav has a pad_width of : 24
# 8797
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold11/213156__arnaud-coutancier__broken-bottle-verre-01.wav has a pad_width of : 210
# 8798
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold11/216280__rsilveira-88__breaking-glass-21.wav has a pad_width of : 173
# 8799
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold11/344269__inspectorj__glass-smash-bottle-h.wav has a pad_width of : 137
# 8800
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold11/349240__natty23__glass-break-2.wav has a pad_width of : 212
# 8801
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold11/368328__johandeecke__glass-hit-16.wav has a pad_width of : 242
# 8802
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold11/368328__johandeecke__glass-hit-16.wav has a pad_width of : 242
# 8803
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold11/368335__johandeecke__glass-hit-36.wav has a pad_width of : 234
# 8804
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold11/368336__johandeecke__glass-hit-3.wav has a pad_width of : 239
# 8805
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold11/368355__johandeecke__glass-hit-4.wav has a pad_width of : 242
# 8806
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold11/368356__johandeecke__glass-hit-7.wav has a pad_width of : 244
# 8807
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold11/371093__mccormick-iain__glass-break-2.wav has a pad_width of : 209
# 8808
# C:\Users\forge\Desktop\MLFolder\UrbanSound8K\audio\fold11/368334__johandeecke__glass-hit-35.wav has a pad_width of : 227
# Finished feature extraction from  8809  files

# %%
from sklearn.preprocessing import LabelEncoder
from keras.utils import to_categorical

# Convert features and corresponding classification labels into numpy arrays
X = np.array(featuresdf.feature.tolist())
y = np.array(featuresdf.class_label.tolist())

# Encode the classification labels
le = LabelEncoder()
yy = to_categorical(le.fit_transform(y)) 

# split the dataset 
from sklearn.model_selection import train_test_split 

x_train, x_test, y_train, y_test = train_test_split(X, yy, test_size=0.2, random_state = 42)

# %% [markdown]
# ### Convolutional Neural Network (CNN) model architecture
#
#
# We will modify our model to be a Convolutional Neural Network (CNN) again using Keras and a Tensorflow backend.
#
# Again we will use a `sequential` model, starting with a simple model architecture, consisting of four `Conv2D` convolution layers, with our final output layer being a `dense` layer.
#
# The convolution layers are designed for feature detection. It works by sliding a filter window over the input and performing a matrix multiplication and storing the result in a feature map. This operation is known as a convolution.
#
#
# The `filter` parameter specifies the number of nodes in each layer. Each layer will increase in size from 16, 32, 64 to 128, while the `kernel_size` parameter specifies the size of the kernel window which in this case is 2 resulting in a 2x2 filter matrix.
#
# The first layer will receive the input shape of (40, 174, 1) where 40 is the number of MFCC's 174 is the number of frames taking padding into account and the 1 signifying that the audio is mono.
#
# The activation function we will be using for our convolutional layers is `ReLU` which is the same as our previous model. We will use a smaller `Dropout` value of 20% on our convolutional layers.
#
# Each convolutional layer has an associated pooling layer of `MaxPooling2D` type with the final convolutional layer having a `GlobalAveragePooling2D` type. The pooling layer is do reduce the dimensionality of the model (by reducing the parameters and subsquent computation requirements) which serves to shorten the training time and reduce overfitting. The Max Pooling type takes the maximum size for each window and the Global Average Pooling type takes the average which is suitable for feeding into our `dense` output layer.
#
# Our output layer will have 10 nodes (num_labels) which matches the number of possible classifications. The activation is for our output layer is `softmax`. Softmax makes the output sum up to 1 so the output can be interpreted as probabilities. The model will then make its prediction based on which option has the highest probability.

# %%
import numpy as np
from keras.models import Sequential
from keras.layers import Dense, Dropout, Activation, Flatten
from keras.layers import Convolution2D, Conv2D, MaxPooling2D, GlobalAveragePooling2D
from keras.optimizers import Adam
from keras.utils import np_utils
from sklearn import metrics 

num_rows = 40
num_columns = max_pad_len
num_channels = 1

x_train = x_train.reshape(x_train.shape[0], num_rows, num_columns, num_channels)
x_test = x_test.reshape(x_test.shape[0], num_rows, num_columns, num_channels)

num_labels = yy.shape[1]
filter_size = 2

# Construct model 
model = Sequential()
model.add(Conv2D(filters=16, kernel_size=2, input_shape=(num_rows, num_columns, num_channels), activation='relu'))
model.add(MaxPooling2D(pool_size=2))
model.add(Dropout(0.2))

model.add(Conv2D(filters=32, kernel_size=2, activation='relu'))
model.add(MaxPooling2D(pool_size=2))
model.add(Dropout(0.2))

model.add(Conv2D(filters=64, kernel_size=2, activation='relu'))
model.add(MaxPooling2D(pool_size=2))
model.add(Dropout(0.2))

model.add(Conv2D(filters=128, kernel_size=2, activation='relu'))
model.add(MaxPooling2D(pool_size=2))
model.add(Dropout(0.2))
model.add(GlobalAveragePooling2D())

model.add(Dense(num_labels, activation='softmax'))

# %% [markdown]
# ### Compiling the model
#
# For compiling our model, we will use the same three parameters as the previous model:

# %%
# Compile the model
model.compile(loss='categorical_crossentropy', metrics=['accuracy'], optimizer='adam')

# %%
# Display model architecture summary 
model.summary()

# Calculate pre-training accuracy 
score = model.evaluate(x_test, y_test, verbose=1)
accuracy = 100*score[1]

print("Pre-training accuracy: %.4f%%" % accuracy)
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 39, 259, 16)       80
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 19, 129, 16)       0
# _________________________________________________________________
# dropout (Dropout)            (None, 19, 129, 16)       0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 18, 128, 32)       2080
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 9, 64, 32)         0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 9, 64, 32)         0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 8, 63, 64)         8256
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 4, 31, 64)         0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 4, 31, 64)         0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 3, 30, 128)        32896
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 1, 15, 128)        0
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 1, 15, 128)        0
# _________________________________________________________________
# global_average_pooling2d (Gl (None, 128)               0
# _________________________________________________________________
# dense (Dense)                (None, 11)                1419
# =================================================================
# Total params: 44,731
# Trainable params: 44,731
# Non-trainable params: 0
# _________________________________________________________________
# 56/56 [==============================] - 1s 11ms/step - loss: 4.4811 - accuracy: 0.1623
# Pre-training accuracy: 16.8558%

# %% [markdown]
# ### Training
#
# Here we will train the model. As training a CNN can take a sigificant amount of time, we will start with a low number of epochs and a low batch size. If we can see from the output that the model is converging, we will increase both numbers.

# %%
from keras.callbacks import ModelCheckpoint 
from datetime import datetime 

#num_epochs = 12
#num_batch_size = 128

num_epochs = 72
num_batch_size = 256

checkpointer = ModelCheckpoint(filepath='saved_models/weights.best.basic_cnn.hdf5', 
                               verbose=1, save_best_only=True)
start = datetime.now()

model.fit(x_train, y_train, batch_size=num_batch_size, epochs=num_epochs, validation_data=(x_test, y_test), callbacks=[checkpointer], verbose=1)


duration = datetime.now() - start
print("Training completed in time: ", duration)
# Out:
# Epoch 1/72
# 28/28 [==============================] - 12s 433ms/step - loss: 3.0911 - accuracy: 0.1961 - val_loss: 2.0640 - val_accuracy: 0.2367
#
# Epoch 00001: val_loss improved from inf to 2.06402, saving model to saved_models\weights.best.basic_cnn.hdf5
# Epoch 2/72
# 28/28 [==============================] - 11s 406ms/step - loss: 1.8041 - accuracy: 0.3560 - val_loss: 1.7767 - val_accuracy: 0.4330
#
# Epoch 00002: val_loss improved from 2.06402 to 1.77670, saving model to saved_models\weights.best.basic_cnn.hdf5
# Epoch 3/72
# 28/28 [==============================] - 11s 407ms/step - loss: 1.5733 - accuracy: 0.4513 - val_loss: 1.5406 - val_accuracy: 0.5221
#
# Epoch 00003: val_loss improved from 1.77670 to 1.54057, saving model to saved_models\weights.best.basic_cnn.hdf5
# Epoch 4/72
# 28/28 [==============================] - 11s 407ms/step - loss: 1.4574 - accuracy: 0.4975 - val_loss: 1.4971 - val_accuracy: 0.5448
#
# Epoch 00004: val_loss improved from 1.54057 to 1.49707, saving model to saved_models\weights.best.basic_cnn.hdf5
# Epoch 5/72
# 28/28 [==============================] - 11s 407ms/step - loss: 1.3264 - accuracy: 0.5466 - val_loss: 1.3769 - val_accuracy: 0.5715
#
# Epoch 00005: val_loss improved from 1.49707 to 1.37691, saving model to saved_models\weights.best.basic_cnn.hdf5
# Epoch 6/72
# 28/28 [==============================] - 11s 412ms/step - loss: 1.2606 - accuracy: 0.5679 - val_loss: 1.3342 - val_accuracy: 0.5636
#
# Epoch 00006: val_loss improved from 1.37691 to 1.33422, saving model to saved_models\weights.best.basic_cnn.hdf5
# Epoch 7/72
# 28/28 [==============================] - 11s 408ms/step - loss: 1.1888 - accuracy: 0.5946 - val_loss: 1.2585 - val_accuracy: 0.6016
#
# Epoch 00007: val_loss improved from 1.33422 to 1.25846, saving model to saved_models\weights.best.basic_cnn.hdf5
# Epoch 8/72
# 28/28 [==============================] - 11s 408ms/step - loss: 1.1207 - accuracy: 0.6190 - val_loss: 1.2052 - val_accuracy: 0.6169
#
# Epoch 00008: val_loss improved from 1.25846 to 1.20519, saving model to saved_models\weights.best.basic_cnn.hdf5
# Epoch 9/72
# 28/28 [==============================] - 11s 408ms/step - loss: 1.0804 - accuracy: 0.6251 - val_loss: 1.1581 - val_accuracy: 0.6362
#
# Epoch 00009: val_loss improved from 1.20519 to 1.15806, saving model to saved_models\weights.best.basic_cnn.hdf5
# Epoch 10/72
# 28/28 [==============================] - 11s 408ms/step - loss: 1.0259 - accuracy: 0.6472 - val_loss: 1.0986 - val_accuracy: 0.6407
#
# Epoch 00010: val_loss improved from 1.15806 to 1.09862, saving model to saved_models\weights.best.basic_cnn.hdf5
# Epoch 11/72
# 28/28 [==============================] - 11s 407ms/step - loss: 0.9840 - accuracy: 0.6696 - val_loss: 1.0410 - val_accuracy: 0.6680
#
# Epoch 00011: val_loss improved from 1.09862 to 1.04102, saving model to saved_models\weights.best.basic_cnn.hdf5
# Epoch 12/72
# 28/28 [==============================] - 11s 409ms/step - loss: 0.9273 - accuracy: 0.6799 - val_loss: 1.0069 - val_accuracy: 0.6646
#
# Epoch 00012: val_loss improved from 1.04102 to 1.00686, saving model to saved_models\weights.best.basic_cnn.hdf5
# Epoch 13/72
# 28/28 [==============================] - 11s 408ms/step - loss: 0.8896 - accuracy: 0.6952 - val_loss: 0.9381 - val_accuracy: 0.7049
#
# Epoch 00013: val_loss improved from 1.00686 to 0.93815, saving model to saved_models\weights.best.basic_cnn.hdf5
# Epoch 14/72
# 28/28 [==============================] - 11s 406ms/step - loss: 0.8521 - accuracy: 0.7111 - val_loss: 0.9068 - val_accuracy: 0.7151
#
# Epoch 00014: val_loss improved from 0.93815 to 0.90678, saving model to saved_models\weights.best.basic_cnn.hdf5
# Epoch 15/72
# 28/28 [==============================] - 11s 409ms/step - loss: 0.8326 - accuracy: 0.7155 - val_loss: 0.9116 - val_accuracy: 0.7094
#
# Epoch 00015: val_loss did not improve from 0.90678
# Epoch 16/72
# 28/28 [==============================] - 11s 408ms/step - loss: 0.8216 - accuracy: 0.7187 - val_loss: 0.8559 - val_accuracy: 0.7321
#
# Epoch 00016: val_loss improved from 0.90678 to 0.85592, saving model to saved_models\weights.best.basic_cnn.hdf5
# Epoch 17/72
# 28/28 [==============================] - 11s 407ms/step - loss: 0.7730 - accuracy: 0.7378 - val_loss: 0.8309 - val_accuracy: 0.7378
#
# Epoch 00017: val_loss improved from 0.85592 to 0.83088, saving model to saved_models\weights.best.basic_cnn.hdf5
# Epoch 18/72
# 28/28 [==============================] - 12s 421ms/step - loss: 0.7494 - accuracy: 0.7480 - val_loss: 0.7812 - val_accuracy: 0.7543
#
# Epoch 00018: val_loss improved from 0.83088 to 0.78124, saving model to saved_models\weights.best.basic_cnn.hdf5
# Epoch 19/72
# 28/28 [==============================] - 12s 411ms/step - loss: 0.7252 - accuracy: 0.7512 - val_loss: 0.7533 - val_accuracy: 0.7650
#
# Epoch 00019: val_loss improved from 0.78124 to 0.75326, saving model to saved_models\weights.best.basic_cnn.hdf5
# Epoch 20/72
# 28/28 [==============================] - 11s 407ms/step - loss: 0.7206 - accuracy: 0.7568 - val_loss: 0.7515 - val_accuracy: 0.7628
#
# Epoch 00020: val_loss improved from 0.75326 to 0.75152, saving model to saved_models\weights.best.basic_cnn.hdf5
# Epoch 21/72
# 28/28 [==============================] - 11s 409ms/step - loss: 0.6887 - accuracy: 0.7642 - val_loss: 0.7364 - val_accuracy: 0.7707
#
# Epoch 00021: val_loss improved from 0.75152 to 0.73645, saving model to saved_models\weights.best.basic_cnn.hdf5
# Epoch 22/72
# 28/28 [==============================] - 11s 406ms/step - loss: 0.6532 - accuracy: 0.7786 - val_loss: 0.6933 - val_accuracy: 0.7832
#
# Epoch 00022: val_loss improved from 0.73645 to 0.69334, saving model to saved_models\weights.best.basic_cnn.hdf5
# Epoch 23/72
# 28/28 [==============================] - 11s 407ms/step - loss: 0.6498 - accuracy: 0.7802 - val_loss: 0.6853 - val_accuracy: 0.7821
#
# Epoch 00023: val_loss improved from 0.69334 to 0.68533, saving model to saved_models\weights.best.basic_cnn.hdf5
# Epoch 24/72
# 28/28 [==============================] - 11s 407ms/step - loss: 0.6332 - accuracy: 0.7835 - val_loss: 0.7059 - val_accuracy: 0.7696
#
# Epoch 00024: val_loss did not improve from 0.68533
# Epoch 25/72
# 28/28 [==============================] - 11s 408ms/step - loss: 0.6330 - accuracy: 0.7849 - val_loss: 0.6969 - val_accuracy: 0.7736
#
# Epoch 00025: val_loss did not improve from 0.68533
# Epoch 26/72
# 28/28 [==============================] - 11s 409ms/step - loss: 0.5921 - accuracy: 0.8042 - val_loss: 0.6471 - val_accuracy: 0.7974
#
# Epoch 00026: val_loss improved from 0.68533 to 0.64711, saving model to saved_models\weights.best.basic_cnn.hdf5
# Epoch 27/72
# 28/28 [==============================] - 12s 412ms/step - loss: 0.5976 - accuracy: 0.8030 - val_loss: 0.6097 - val_accuracy: 0.8110
#
# Epoch 00027: val_loss improved from 0.64711 to 0.60966, saving model to saved_models\weights.best.basic_cnn.hdf5
# Epoch 28/72
# 28/28 [==============================] - 12s 420ms/step - loss: 0.5646 - accuracy: 0.8148 - val_loss: 0.6589 - val_accuracy: 0.7849
#
# Epoch 00028: val_loss did not improve from 0.60966
# Epoch 29/72
# 28/28 [==============================] - 11s 407ms/step - loss: 0.5838 - accuracy: 0.8029 - val_loss: 0.6130 - val_accuracy: 0.8082
#
# Epoch 00029: val_loss did not improve from 0.60966
# Epoch 30/72
# 28/28 [==============================] - 11s 407ms/step - loss: 0.5424 - accuracy: 0.8185 - val_loss: 0.5844 - val_accuracy: 0.8178
#
# Epoch 00030: val_loss improved from 0.60966 to 0.58439, saving model to saved_models\weights.best.basic_cnn.hdf5
# Epoch 31/72
# 28/28 [==============================] - 11s 406ms/step - loss: 0.5238 - accuracy: 0.8202 - val_loss: 0.5963 - val_accuracy: 0.8110
#
# Epoch 00031: val_loss did not improve from 0.58439
# Epoch 32/72
# 28/28 [==============================] - 11s 409ms/step - loss: 0.5260 - accuracy: 0.8259 - val_loss: 0.5513 - val_accuracy: 0.8184
#
# Epoch 00032: val_loss improved from 0.58439 to 0.55126, saving model to saved_models\weights.best.basic_cnn.hdf5
# Epoch 33/72
# 28/28 [==============================] - 12s 416ms/step - loss: 0.5062 - accuracy: 0.8300 - val_loss: 0.5593 - val_accuracy: 0.8207
#
# Epoch 00033: val_loss did not improve from 0.55126
# Epoch 34/72
# 28/28 [==============================] - 11s 411ms/step - loss: 0.4869 - accuracy: 0.8408 - val_loss: 0.5657 - val_accuracy: 0.8178
# Epoch 00034: val_loss did not improve from 0.55126
# Epoch 35/72
# 28/28 [==============================] - 11s 409ms/step - loss: 0.4741 - accuracy: 0.8391 - val_loss: 0.5439 - val_accuracy: 0.8286
#
# Epoch 00035: val_loss improved from 0.55126 to 0.54393, saving model to saved_models\weights.best.basic_cnn.hdf5
# Epoch 36/72
# 28/28 [==============================] - 11s 408ms/step - loss: 0.4869 - accuracy: 0.8360 - val_loss: 0.5169 - val_accuracy: 0.8280
#
# Epoch 00036: val_loss improved from 0.54393 to 0.51695, saving model to saved_models\weights.best.basic_cnn.hdf5
# Epoch 37/72
# 28/28 [==============================] - 11s 407ms/step - loss: 0.4563 - accuracy: 0.8490 - val_loss: 0.5103 - val_accuracy: 0.8326
#
# Epoch 00037: val_loss improved from 0.51695 to 0.51029, saving model to saved_models\weights.best.basic_cnn.hdf5
# Epoch 38/72
# 28/28 [==============================] - 11s 409ms/step - loss: 0.4440 - accuracy: 0.8483 - val_loss: 0.5168 - val_accuracy: 0.8303
#
# Epoch 00038: val_loss did not improve from 0.51029
# Epoch 39/72
# 28/28 [==============================] - 11s 412ms/step - loss: 0.4411 - accuracy: 0.8480 - val_loss: 0.5028 - val_accuracy: 0.8383
#
# Epoch 00039: val_loss improved from 0.51029 to 0.50279, saving model to saved_models\weights.best.basic_cnn.hdf5
# Epoch 40/72
# 28/28 [==============================] - 12s 414ms/step - loss: 0.4482 - accuracy: 0.8533 - val_loss: 0.4886 - val_accuracy: 0.8394
#
# Epoch 00040: val_loss improved from 0.50279 to 0.48856, saving model to saved_models\weights.best.basic_cnn.hdf5
# Epoch 41/72
# 28/28 [==============================] - 11s 406ms/step - loss: 0.4309 - accuracy: 0.8589 - val_loss: 0.4892 - val_accuracy: 0.8422
#
# Epoch 00041: val_loss did not improve from 0.48856
# Epoch 42/72
# 28/28 [==============================] - 11s 407ms/step - loss: 0.4139 - accuracy: 0.8639 - val_loss: 0.4512 - val_accuracy: 0.8547
#
# Epoch 00042: val_loss improved from 0.48856 to 0.45121, saving model to saved_models\weights.best.basic_cnn.hdf5
# Epoch 43/72
# 28/28 [==============================] - 11s 406ms/step - loss: 0.4155 - accuracy: 0.8606 - val_loss: 0.4686 - val_accuracy: 0.8502
#
# Epoch 00043: val_loss did not improve from 0.45121
# Epoch 44/72
# 28/28 [==============================] - 11s 407ms/step - loss: 0.4019 - accuracy: 0.8605 - val_loss: 0.4677 - val_accuracy: 0.8496
#
# Epoch 00044: val_loss did not improve from 0.45121
# Epoch 45/72
# 28/28 [==============================] - 11s 406ms/step - loss: 0.3956 - accuracy: 0.8606 - val_loss: 0.4341 - val_accuracy: 0.8655
#
# Epoch 00045: val_loss improved from 0.45121 to 0.43405, saving model to saved_models\weights.best.basic_cnn.hdf5
# Epoch 46/72
# 28/28 [==============================] - 11s 411ms/step - loss: 0.3911 - accuracy: 0.8675 - val_loss: 0.5053 - val_accuracy: 0.8314
#
# Epoch 00046: val_loss did not improve from 0.43405
# Epoch 47/72
# 28/28 [==============================] - 12s 414ms/step - loss: 0.3818 - accuracy: 0.8744 - val_loss: 0.4719 - val_accuracy: 0.8439
#
# Epoch 00047: val_loss did not improve from 0.43405
# Epoch 48/72
# 28/28 [==============================] - 12s 416ms/step - loss: 0.3869 - accuracy: 0.8699 - val_loss: 0.4211 - val_accuracy: 0.8683
#
# Epoch 00048: val_loss improved from 0.43405 to 0.42106, saving model to saved_models\weights.best.basic_cnn.hdf5
# Epoch 49/72
# 28/28 [==============================] - 12s 415ms/step - loss: 0.3843 - accuracy: 0.8656 - val_loss: 0.4352 - val_accuracy: 0.8564
#
# Epoch 00049: val_loss did not improve from 0.42106
# Epoch 50/72
# 28/28 [==============================] - 11s 409ms/step - loss: 0.3638 - accuracy: 0.8801 - val_loss: 0.4393 - val_accuracy: 0.8564
#
# Epoch 00050: val_loss did not improve from 0.42106
# Epoch 51/72
# 28/28 [==============================] - 11s 409ms/step - loss: 0.3453 - accuracy: 0.8868 - val_loss: 0.4233 - val_accuracy: 0.8661
#
# Epoch 00051: val_loss did not improve from 0.42106
# Epoch 52/72
# 28/28 [==============================] - 11s 406ms/step - loss: 0.3451 - accuracy: 0.8804 - val_loss: 0.3995 - val_accuracy: 0.8678
#
# Epoch 00052: val_loss improved from 0.42106 to 0.39945, saving model to saved_models\weights.best.basic_cnn.hdf5
# Epoch 53/72
# 28/28 [==============================] - 11s 406ms/step - loss: 0.3442 - accuracy: 0.8845 - val_loss: 0.4113 - val_accuracy: 0.8632
#
# Epoch 00053: val_loss did not improve from 0.39945
# Epoch 54/72
# 28/28 [==============================] - 11s 408ms/step - loss: 0.3369 - accuracy: 0.8859 - val_loss: 0.4132 - val_accuracy: 0.8661
#
# Epoch 00054: val_loss did not improve from 0.39945
# Epoch 55/72
# 28/28 [==============================] - 11s 411ms/step - loss: 0.3260 - accuracy: 0.8910 - val_loss: 0.4109 - val_accuracy: 0.8604
#
# Epoch 00055: val_loss did not improve from 0.39945
# Epoch 56/72
# 28/28 [==============================] - 12s 426ms/step - loss: 0.3189 - accuracy: 0.8917 - val_loss: 0.3581 - val_accuracy: 0.8848
#
# Epoch 00056: val_loss improved from 0.39945 to 0.35813, saving model to saved_models\weights.best.basic_cnn.hdf5
# Epoch 57/72
# 28/28 [==============================] - 12s 429ms/step - loss: 0.3235 - accuracy: 0.8951 - val_loss: 0.4354 - val_accuracy: 0.8581
#
# Epoch 00057: val_loss did not improve from 0.35813
# Epoch 58/72
# 28/28 [==============================] - 11s 409ms/step - loss: 0.3170 - accuracy: 0.8919 - val_loss: 0.4298 - val_accuracy: 0.8570
#
# Epoch 00058: val_loss did not improve from 0.35813
# Epoch 59/72
# 28/28 [==============================] - 11s 406ms/step - loss: 0.2986 - accuracy: 0.8960 - val_loss: 0.3997 - val_accuracy: 0.8689
#
# Epoch 00059: val_loss did not improve from 0.35813
# Epoch 60/72
# 28/28 [==============================] - 12s 419ms/step - loss: 0.3099 - accuracy: 0.8995 - val_loss: 0.3575 - val_accuracy: 0.8859
#
# Epoch 00060: val_loss improved from 0.35813 to 0.35750, saving model to saved_models\weights.best.basic_cnn.hdf5
# Epoch 61/72
# 28/28 [==============================] - 11s 405ms/step - loss: 0.3090 - accuracy: 0.8929 - val_loss: 0.3929 - val_accuracy: 0.8797
#
# Epoch 00061: val_loss did not improve from 0.35750
# Epoch 62/72
# 28/28 [==============================] - 12s 433ms/step - loss: 0.2980 - accuracy: 0.8987 - val_loss: 0.4216 - val_accuracy: 0.8558
#
# Epoch 00062: val_loss did not improve from 0.35750
# Epoch 63/72
# 28/28 [==============================] - 12s 411ms/step - loss: 0.2786 - accuracy: 0.9055 - val_loss: 0.3507 - val_accuracy: 0.8865
#
# Epoch 00063: val_loss improved from 0.35750 to 0.35071, saving model to saved_models\weights.best.basic_cnn.hdf5
# Epoch 64/72
# 28/28 [==============================] - 11s 405ms/step - loss: 0.2815 - accuracy: 0.9031 - val_loss: 0.3797 - val_accuracy: 0.8746
#
# Epoch 00064: val_loss did not improve from 0.35071
# Epoch 65/72
# 28/28 [==============================] - 11s 406ms/step - loss: 0.2916 - accuracy: 0.9027 - val_loss: 0.3547 - val_accuracy: 0.8842
#
# Epoch 00065: val_loss did not improve from 0.35071
# Epoch 66/72
# 28/28 [==============================] - 11s 408ms/step - loss: 0.2755 - accuracy: 0.9061 - val_loss: 0.3395 - val_accuracy: 0.8882
#
# Epoch 00066: val_loss improved from 0.35071 to 0.33948, saving model to saved_models\weights.best.basic_cnn.hdf5
# Epoch 67/72
# 28/28 [==============================] - 11s 408ms/step - loss: 0.2844 - accuracy: 0.9010 - val_loss: 0.3442 - val_accuracy: 0.8876
#
# Epoch 00067: val_loss did not improve from 0.33948
# Epoch 68/72
# 28/28 [==============================] - 11s 407ms/step - loss: 0.2612 - accuracy: 0.9100 - val_loss: 0.3223 - val_accuracy: 0.8939
#
# Epoch 00068: val_loss improved from 0.33948 to 0.32230, saving model to saved_models\weights.best.basic_cnn.hdf5
# Epoch 69/72
# 28/28 [==============================] - 11s 407ms/step - loss: 0.2677 - accuracy: 0.9078 - val_loss: 0.3395 - val_accuracy: 0.8888
#
# Epoch 00069: val_loss did not improve from 0.32230
# Epoch 70/72
# 28/28 [==============================] - 12s 419ms/step - loss: 0.2514 - accuracy: 0.9116 - val_loss: 0.3329 - val_accuracy: 0.8905
#
# Epoch 00070: val_loss did not improve from 0.32230
# Epoch 71/72
# 28/28 [==============================] - 12s 411ms/step - loss: 0.2559 - accuracy: 0.9133 - val_loss: 0.3354 - val_accuracy: 0.8837
#
# Epoch 00071: val_loss did not improve from 0.32230
# Epoch 72/72
# 28/28 [==============================] - 11s 409ms/step - loss: 0.2663 - accuracy: 0.9110 - val_loss: 0.3400 - val_accuracy: 0.8820
#
# Epoch 00072: val_loss did not improve from 0.32230
# Training completed in time:  0:13:47.676954

# %%
model.save('C:\Users\forge\Desktop\MLFolder\Sec\SavedModel')
# Out:
#   File "<ipython-input-9-0d228eb3a602>", line 1
#     model.save('C:\Users\forge\Desktop\MLFolder\Sec\SavedModel')
#                ^
# SyntaxError: (unicode error) 'unicodeescape' codec can't decode bytes in position 2-3: truncated \UXXXXXXXX escape

# %% [markdown]
# ### Test the model
#
# Here we will review the accuracy of the model on both the training and test data sets.

# %%
# Evaluating the model on the training and testing set
score = model.evaluate(x_train, y_train, verbose=0)
print("Training Accuracy: ", score[1])

score = model.evaluate(x_test, y_test, verbose=0)
print("Testing Accuracy: ", score[1])
# Out:
# Training Accuracy:  0.9399744868278503
# Testing Accuracy:  0.8819523453712463

# %% [markdown]
# The Training and Testing accuracy scores are both high and an increase on our initial model. Training accuracy has increased by ~6% and Testing accuracy has increased by ~4%.
#
# There is a marginal increase in the difference between the Training and Test scores (~6% compared to ~5% previously) though the difference remains low so the model has not suffered from overfitting.

# %% [markdown]
# ### Predictions
#
# Here we will modify our previous method for testing the models predictions on a specified audio .wav file.

# %%
def print_prediction(file_name):
    prediction_feature = extract_features(file_name) 
    prediction_feature = prediction_feature.reshape(1, num_rows, num_columns, num_channels)

    predicted_vector = model.predict_classes(prediction_feature)
    predicted_class = le.inverse_transform(predicted_vector) 
    print("The predicted class is:", predicted_class[0], '\n') 

    predicted_proba_vector = model.predict_proba(prediction_feature) 
    predicted_proba = predicted_proba_vector[0]
    for i in range(len(predicted_proba)): 
        category = le.inverse_transform(np.array([i]))
        print(category[0], "\t\t : ", format(predicted_proba[i], '.32f') )

# %% [markdown]
# ### Validation
#
# #### Test with sample data
#
# As before we will verify the predictions using a subsection of the sample audio files we explored in the first notebook. We expect the bulk of these to be classified correctly.

# %%
# Class: Air Conditioner

filename = '../UrbanSound Dataset sample/audio/100852-0-0-0.wav' 
print_prediction(filename)
# Out:
# ../UrbanSound Dataset sample/audio/100852-0-0-0.wav has a pad_width of : 87
# The predicted class is: air_conditioner
#
# air_conditioner 		 :  0.93532299995422363281250000000000
# car_horn 		 :  0.00000228979229177639354020357132
# children_playing 		 :  0.00480040349066257476806640625000
# dog_bark 		 :  0.00013096509792376309633255004883
# drilling 		 :  0.00454284390434622764587402343750
# engine_idling 		 :  0.01088122557848691940307617187500
# glass_breaking 		 :  0.00004454193185665644705295562744
# gun_shot 		 :  0.00176859204657375812530517578125
# jackhammer 		 :  0.04069950431585311889648437500000
# siren 		 :  0.00024775377823971211910247802734
# street_music 		 :  0.00155887752771377563476562500000
# C:\Users\forge\anaconda3\lib\site-packages\tensorflow\python\keras\engine\sequential.py:450: UserWarning: `model.predict_classes()` is deprecated and will be removed after 2021-01-01. Please use instead:* `np.argmax(model.predict(x), axis=-1)`,   if your model does multi-class classification   (e.g. if it uses a `softmax` last-layer activation).* `(model.predict(x) > 0.5).astype("int32")`,   if your model does binary classification   (e.g. if it uses a `sigmoid` last-layer activation).
#   warnings.warn('`model.predict_classes()` is deprecated and '
# C:\Users\forge\anaconda3\lib\site-packages\tensorflow\python\keras\engine\sequential.py:425: UserWarning: `model.predict_proba()` is deprecated and will be removed after 2021-01-01. Please use `model.predict()` instead.
#   warnings.warn('`model.predict_proba()` is deprecated and '

# %%
# Class: Drilling

filename = '../UrbanSound Dataset sample/audio/103199-4-0-0.wav'
print_prediction(filename)
# Out:
# ../UrbanSound Dataset sample/audio/103199-4-0-0.wav has a pad_width of : 87
# The predicted class is: drilling
#
# air_conditioner 		 :  0.00000005919219248085028084460646
# car_horn 		 :  0.00763118499889969825744628906250
# children_playing 		 :  0.00000049736968321667518466711044
# dog_bark 		 :  0.00000336509424414543900638818741
# drilling 		 :  0.98415565490722656250000000000000
# engine_idling 		 :  0.00000000286083423617355947499163
# glass_breaking 		 :  0.00000087913417701201979070901871
# gun_shot 		 :  0.00000000012155373929623181084025
# jackhammer 		 :  0.00096053100423887372016906738281
# siren 		 :  0.00000021839139208168489858508110
# street_music 		 :  0.00724773807451128959655761718750

# %%
# Class: Street music 

filename = '../UrbanSound Dataset sample/audio/101848-9-0-0.wav'
print_prediction(filename)
# Out:
# ../UrbanSound Dataset sample/audio/101848-9-0-0.wav has a pad_width of : 87
# The predicted class is: street_music
#
# air_conditioner 		 :  0.00011701828771037980914115905762
# car_horn 		 :  0.00061314541380852460861206054688
# children_playing 		 :  0.01773038320243358612060546875000
# dog_bark 		 :  0.00408619223162531852722167968750
# drilling 		 :  0.00019965367391705513000488281250
# engine_idling 		 :  0.00004729490319732576608657836914
# glass_breaking 		 :  0.00000011713456871120797586627305
# gun_shot 		 :  0.00000000178950032569957784289727
# jackhammer 		 :  0.00000339189250553317833691835403
# siren 		 :  0.00186337367631494998931884765625
# street_music 		 :  0.97533947229385375976562500000000

# %%
# Class: Car Horn 

filename = '../UrbanSound Dataset sample/audio/100648-1-0-0.wav'
print_prediction(filename)
# Out:
# ../UrbanSound Dataset sample/audio/100648-1-0-0.wav has a pad_width of : 232
# The predicted class is: drilling
#
# air_conditioner 		 :  0.00329582300037145614624023437500
# car_horn 		 :  0.16508534550666809082031250000000
# children_playing 		 :  0.00776174059137701988220214843750
# dog_bark 		 :  0.10962965339422225952148437500000
# drilling 		 :  0.26490539312362670898437500000000
# engine_idling 		 :  0.03766566514968872070312500000000
# glass_breaking 		 :  0.01892982237040996551513671875000
# gun_shot 		 :  0.16260311007499694824218750000000
# jackhammer 		 :  0.20086525380611419677734375000000
# siren 		 :  0.01748805865645408630371093750000
# street_music 		 :  0.01177007518708705902099609375000

# %% [markdown]
# #### Observations
#
# We can see that the model performs well.
#
# Interestingly, car horn was again incorrectly classifed but this time as drilling - though the per class confidence shows it was a close decision between car horn with 26% confidence and drilling at 34% confidence.

# %% [markdown]
# ### Other audio
#
# Again we will further validate our model using a sample of various copyright free sounds that we not part of either our test or training data.

# %%
filename = '../Evaluation audio/dog_bark_1.wav'
print_prediction(filename)
# Out:
# ../Evaluation audio/dog_bark_1.wav has a pad_width of : 222
# The predicted class is: dog_bark
#
# air_conditioner 		 :  0.00039293814916163682937622070312
# car_horn 		 :  0.12112177908420562744140625000000
# children_playing 		 :  0.01435600407421588897705078125000
# dog_bark 		 :  0.59988671541213989257812500000000
# drilling 		 :  0.10404328256845474243164062500000
# engine_idling 		 :  0.00856282189488410949707031250000
# glass_breaking 		 :  0.00042224710341542959213256835938
# gun_shot 		 :  0.12315442413091659545898437500000
# jackhammer 		 :  0.01725470460951328277587890625000
# siren 		 :  0.00464432640001177787780761718750
# street_music 		 :  0.00616060337051749229431152343750

# %%
filename = '../Evaluation audio/drilling_1.wav'

print_prediction(filename)
# Out:
# ../Evaluation audio/drilling_1.wav has a pad_width of : 149
# The predicted class is: jackhammer
#
# air_conditioner 		 :  0.02154975570738315582275390625000
# car_horn 		 :  0.00002585999027360230684280395508
# children_playing 		 :  0.00041766106733120977878570556641
# dog_bark 		 :  0.00071591208688914775848388671875
# drilling 		 :  0.03276121616363525390625000000000
# engine_idling 		 :  0.09177129715681076049804687500000
# glass_breaking 		 :  0.00075572490459308028221130371094
# gun_shot 		 :  0.00001439152129023568704724311829
# jackhammer 		 :  0.84554082155227661132812500000000
# siren 		 :  0.00580954924225807189941406250000
# street_music 		 :  0.00063775538001209497451782226562

# %%
filename = '../Evaluation audio/gun_shot_1.wav'

print_prediction(filename)
# Out:
# ../Evaluation audio/gun_shot_1.wav has a pad_width of : 128
# The predicted class is: gun_shot
#
# air_conditioner 		 :  0.00002034652425209060311317443848
# car_horn 		 :  0.00001599263487150892615318298340
# children_playing 		 :  0.00076687673572450876235961914062
# dog_bark 		 :  0.02608784474432468414306640625000
# drilling 		 :  0.01149901654571294784545898437500
# engine_idling 		 :  0.00058349448954686522483825683594
# glass_breaking 		 :  0.02385033480823040008544921875000
# gun_shot 		 :  0.93344968557357788085937500000000
# jackhammer 		 :  0.00001700787652225699275732040405
# siren 		 :  0.00064897083211690187454223632812
# street_music 		 :  0.00306041655130684375762939453125

# %%
filename = '../Evaluation audio/glass_break_1.wav'

print_prediction(filename)
# Out:
# ../Evaluation audio/glass_break_1.wav has a pad_width of : 32
# The predicted class is: glass_breaking
#
# air_conditioner 		 :  0.00000000010900256391943585754234
# car_horn 		 :  0.00000011054287085698888404294848
# children_playing 		 :  0.00029248182545416057109832763672
# dog_bark 		 :  0.00185980065725743770599365234375
# drilling 		 :  0.00007573183393105864524841308594
# engine_idling 		 :  0.00000000084669787847602151487081
# glass_breaking 		 :  0.99765467643737792968750000000000
# gun_shot 		 :  0.00010169338202103972434997558594
# jackhammer 		 :  0.00000000002837006324307722593403
# siren 		 :  0.00000004329053027163354272488505
# street_music 		 :  0.00001544211227155756205320358276

# %% [markdown]
# #### Observations
#
# The performance of our final model is very good and has generalised well, seeming to predict well when tested against new audio data.
